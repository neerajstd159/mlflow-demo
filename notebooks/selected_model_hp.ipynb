# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
import os

# %%
df = pd.read_csv('https://raw.githubusercontent.com/campusx-official/jupyter-masterclass/main/tweet_emotions.csv').drop(columns=['tweet_id'])
df.head()
# Out:
#     sentiment                                            content
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
import re

def lower_case(text):
    text = [word.lower() for word in text.split()]
    return " ".join(text)


def replace_pattern(pattern, text):
    text = re.sub(pattern, ' ', text)
    return text


def replace_pattern_with_pattern(pattern1, pattern2, text):
    text = re.sub(pattern1, pattern2, text)
    return text

# %%
df['content'] = df['content'].apply(lambda x: lower_case(x))
url_pattern = r'https?://[^\s]*|www\.[^\s]*'
user_pattern = r'@[^\s]*'
df['content'] = df['content'].apply(lambda x: replace_pattern(url_pattern, x))
df['content'] = df['content'].apply(lambda x: replace_pattern(user_pattern, x))
non_alphanumeric_pattern = r'[^a-zA-Z0-9]'
df['content'] = df['content'].apply(lambda x: replace_pattern(non_alphanumeric_pattern, x))
search_pattern = r'(.)\1{2,}'
replace_with = r'\1\1'
df['content'] = df['content'].apply(lambda x: replace_pattern_with_pattern(search_pattern, replace_with, x))

# %%
df.sample(10)
# Out:
#         sentiment                                            content
# 13716  enthusiasm                 i want one so bad get one for me
# 4042         love  i hope you come over today  its almost 8 ill b...
# 33957        love    happy birthday justin  have a lof of fun  go...
# 9962         love    thats what i love about you  you are as sham...
# 30397    surprise  christa s mothers day card  deep in the build ...
# 16865   happiness    good job i have the track in my head  cos sa...
# 8819         love                i wanna go  i wanna go  but i can t
# 27701       worry    yes i know as my school reports would say  m...
# 14791       worry  plus it hurts seeing sum1 you love falling for...
# 30264   happiness                        thank you  yes yes  hooray

# %%
df = df[df['sentiment'].isin(['happiness', 'sadness', 'love'])]

# %%
df['sentiment'] = df['sentiment'].map({'happiness':0, 'love':0, 'sadness':1})

# %%
# remove stopwords
import nltk
from nltk.corpus import stopwords
stopword = set(stopwords.words('english'))

def remove_stopwords(text):
    new_text = [word for word in text.split() if word not in stopword]
    return " ".join(new_text)

df['content'] = df['content'].apply(lambda x: remove_stopwords(x))

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# apply lemmatization
def apply_lemmatization(text):
    new_text = [lemmatizer.lemmatize(word) for word in text.split()]
    return " ".join(new_text)

df['content'] = df['content'].apply(lambda x: apply_lemmatization(x))

# %%
df.head()
# Out:
#    sentiment                                            content
# 1          1              layin n bed headache ughh waitin call
# 2          1                     funeral ceremony gloomy friday
# 6          1  sleep im thinking old friend want married damn...
# 8          1                                 charlene love miss
# 9          1                                 sorry least friday

# %%
import mlflow
import dagshub
mlflow.set_tracking_uri('https://dagshub.com/neerajstd159/mlflow-demo.mlflow')
dagshub.init(repo_owner="neerajstd159", repo_name="mlflow-demo", mlflow=True)
mlflow.set_experiment("Random forest with bow")
# Out:
# Initialized MLflow to track repo "neerajstd159/mlflow-demo"
# Repository neerajstd159/mlflow-demo initialized!
# <Experiment: artifact_location='mlflow-artifacts:/b5f3034bb8a64980b4d6fb7f5622f3d3', creation_time=1734962267570, experiment_id='5', last_update_time=1734962267570, lifecycle_stage='active', name='Random forest with bow', tags={}>

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline([
    ("BoW", CountVectorizer()),
    ("rf", RandomForestClassifier())
])

param_grid = {
    "BoW__max_features": [1000, 2000, 5000],
    "BoW__ngram_range": [(1, 1), (1, 2)],
    "rf__n_estimators": [50, 100, 200],
    "rf__max_depth": [None, 10, 20],
    "rf__min_samples_split": [2, 5, 10],
    "rf__min_samples_leaf": [1, 2, 4],
}

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# Split data
X_train_full, X_test, y_train_full, y_test = train_test_split(df['content'], df['sentiment'], test_size=0.2, random_state=42, stratify=df['sentiment'])
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42, stratify=y_train_full)

with mlflow.start_run() as parent_run:
    grid_search = GridSearchCV(pipeline, param_grid, cv=2, scoring='accuracy', n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)

    # Log each configuration and its performance
    for i, params in enumerate(grid_search.cv_results_['params']):
        with mlflow.start_run(run_name=f"Param_Set_{i+1}", nested=True) as child_run:
            mlflow.log_params(params)
            mean_test_score = grid_search.cv_results_['mean_test_score'][i]
            mlflow.log_metric("mean_cv_accuracy", mean_test_score)
    
    # Get best model and parameters
    best_estimator = grid_search.best_estimator_
    best_params = grid_search.best_params_
    mlflow.log_params(best_params)

    # Validate on test set
    y_pred = best_estimator.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1_scr = f1_score(y_test, y_pred, average='weighted')

    mlflow.log_metric("test_accuracy", accuracy)
    mlflow.log_metric("test_precision", precision)
    mlflow.log_metric("test_recall", recall)
    mlflow.log_metric("test_f1_score", f1_scr)

    # Log confusion matrix as an artifact
    cm_display = ConfusionMatrixDisplay.from_estimator(best_estimator, X_test, y_test, cmap=plt.cm.Blues)
    cm_figure_path = "confusion_matrix.png"
    cm_display.figure_.savefig(cm_figure_path)
    mlflow.log_artifact(cm_figure_path)

    # Save the notebook and log it
    notebook_path = "selected_model_hp.ipynb"
    os.system(f"jupyter nbconvert --to notebook --execute --inplace {notebook_path}")
    mlflow.log_artifact(notebook_path)

    signature = mlflow.models.infer_signature(X_val, best_estimator.predict(X_val))
    mlflow.sklearn.log_model(best_estimator, "best_model", signature=signature)

    # Print the results for verification
    print(f"Test Accuracy: {accuracy:.4f}")
    print(f"Test Precision: {precision:.4f}")
    print(f"Test Recall: {recall:.4f}")
    print(f"Test F1 Score: {f1_scr:.4f}")
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# 🏃 View run Param_Set_1 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/d66f2248c75d43c39cf8dc1b7bba0168
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_2 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/4e7fdcb90a3e4eefa1bd1a458044f1c2
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_3 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/8f55168de29b49aca3336f31252c73ac
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_4 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/942db5b3ad4d4ec0ab4497b36f57df80
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_5 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/86dec0a2417c4551a649f5f98a9f4718
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_6 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/1683b6b31c534b9e88a27a898d9e5f29
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_7 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/e689abc722d74451b788849b28e2789d
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_8 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/48f3efec149e4e348910b974f5e7c734
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_9 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/9df94366bb714ec1a2daa87bb8d259dd
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_10 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/5d2ebe0d2aee4babafbacfa23fd59c18
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_11 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/ab135ba673d64d59aa919d84cbedccf5
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_12 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/d1d5f32555b14404a358edf4a21c39de
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_13 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/60adf56d017d4d579f93f522a11e4781
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_14 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/b8d157b08bc34cfc9f090662277fe61c
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_15 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/fc3944d42b7c48a2a0f5146814a84f81
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_16 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/81d82b87e8524ac2adebc84aa51cb8c8
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_17 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/b48b1b66e1714fdf8586cc0afb465c9e
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_18 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/3cd61dc6bb584eb8b6ae23bad8bbf89c
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_19 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/29331fd50b4b439a888236ae07cd1584
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_20 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/fee3afdece114e5eab988af4a0ffc7eb
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_21 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/944b9ebe6e5b4e99a1a7fe4c8b951eb9
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_22 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/8aa3e4cca0c24169b4f5e5901b5b08e9
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_23 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/6cc989e540a54a10a4399de4ced7e953
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_24 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/5a8a19430ec6477c9f120249de1d204a
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_25 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/d25847da1ee74be4b682ddcfa58fdbf2
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_26 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/e54058465af24aa7911bcaa4616e5ab5
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_27 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/d472c27da2ca408ab44055b80cbe3a7b
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_28 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/c7fbfd8791314b7494611df0ca8a28b2
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_29 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/5ebf19d2e92e43538e265943bc8511b9
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_30 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/5abbb72a773f43759acd6cf9d87ec8d8
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_31 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/c4987b1c208d4787a77228d99181af66
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_32 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/2be14ace85464833b4144e2f3fe3e343
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_33 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/e5937c1e1fb84016a5abc0a50ace7c50
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_34 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/4e86ba020933404083752676bf01960e
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run Param_Set_35 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/adce8cb8d1b14cfe92c3e4050ce2b7f3
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# 🏃 View run beautiful-chimp-319 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5/runs/f98bd01af06a414e8c6ffc215fe8dfc2
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 11
#       9 # Log each configuration and its performance
#      10 for i, params in enumerate(grid_search.cv_results_['params']):
# ---> 11     with mlflow.start_run(run_name=f"Param_Set_{i+1}", nested=True) as child_run:
#      12         mlflow.log_params(params)
#      13         mean_test_score = grid_search.cv_results_['mean_test_score'][i]
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\tracking\fluent.py:229, in ActiveRun.__exit__(self, exc_type, exc_val, exc_tb)
#     227 if any(r.info.run_id == self.info.run_id for r in active_run_stack):
#     228     status = RunStatus.FINISHED if exc_type is None else RunStatus.FAILED
# --> 229     end_run(RunStatus.to_string(status))
#     231 return exc_type is None
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\tracking\fluent.py:519, in end_run(status)
#     517 last_active_run_id = run.info.run_id
#     518 _last_active_run_id.set(last_active_run_id)
# --> 519 MlflowClient().set_terminated(last_active_run_id, status)
#     520 if last_active_run_id in run_id_to_system_metrics_monitor:
#     521     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(last_active_run_id)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\tracking\client.py:2905, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    2860 def set_terminated(
#    2861     self, run_id: str, status: Optional[str] = None, end_time: Optional[int] = None
#    2862 ) -> None:
#    2863     """Set a run's status to terminated.
#    2864
#    2865     Args:
#    (...)
#    2903
#    2904     """
# -> 2905     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:942, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     938 # Tell the store to stop async logging: stop accepting new data and log already enqueued
#     939 # data in the background. This call is making sure every async logging data has been
#     940 # submitted for logging, but not necessarily finished logging.
#     941 self.store.shut_down_async_logging()
# --> 942 self._log_url(run_id)
#     943 self.store.update_run_info(
#     944     run_id,
#     945     run_status=RunStatus.from_string(status),
#     946     end_time=end_time,
#     947     run_name=None,
#     948 )
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:916, in TrackingServiceClient._log_url(self, run_id)
#     914 if host_url is None:
#     915     host_url = self.store.get_host_creds().host.rstrip("/")
# --> 916 run_info = self.store.get_run(run_id).info
#     917 experiment_id = run_info.experiment_id
#     918 run_name = run_info.run_name
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\store\tracking\rest_store.py:169, in RestStore.get_run(self, run_id)
#     159 """
#     160 Fetch the run from backend store
#     161
#    (...)
#     166     A single Run object if it exists, otherwise raises an Exception
#     167 """
#     168 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 169 response_proto = self._call_endpoint(GetRun, req_body)
#     170 return Run.from_proto(response_proto.run)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\utils\rest_utils.py:365, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     363 if method == "GET":
#     364     call_kwargs["params"] = json_body
# --> 365     response = http_request(**call_kwargs)
#     366 else:
#     367     call_kwargs["json"] = json_body
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\utils\rest_utils.py:189, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     186     kwargs["auth"] = fetch_auth(host_creds.auth)
#     188 try:
# --> 189     return _get_http_response_with_retries(
#     190         method,
#     191         url,
#     192         max_retries,
#     193         backoff_factor,
#     194         backoff_jitter,
#     195         retry_codes,
#     196         raise_on_status,
#     197         headers=headers,
#     198         verify=host_creds.verify,
#     199         timeout=timeout,
#     200         respect_retry_after_header=respect_retry_after_header,
#     201         **kwargs,
#     202     )
#     203 except requests.exceptions.Timeout as to:
#     204     raise MlflowException(
#     205         f"API request to {url} failed with timeout exception {to}."
#     206         " To increase the timeout, set the environment variable "
#     207         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     208     ) from to
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\data\projects\mlflow-basic-demo\myenv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File C:\Program Files\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# with mlflow.start_run() as parent_run:
#     grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)
#     grid_search.fit(X_train, y_train)

#     for i, params in enumerate(grid_search.cv_results_['params']):
#         with mlflow.start_run(run_name=f"{i+1}", nested=True) as child_run:

#             mlflow.log_params(params)
#             mean_test_score = grid_search.cv_results_['mean_test_score'][i]
#             mlflow.log_metric("mean_accuracy", mean_test_score)

#     best_estimator = grid_search.best_estimator_
#     best_params = grid_search.best_params_
#     y_pred = best_estimator.predict(X_test)

#     accuracy = accuracy_score(y_pred, y_test)
#     precision = precision_score(y_pred, y_test)
#     f1_scr = f1_score(y_pred, y_test)
#     recall = recall_score(y_pred, y_test)

#     mlflow.log_params(best_params)
#     mlflow.log_metric("accuracy", accuracy)
#     mlflow.log_metric("precision", precision)
#     mlflow.log_metric("recall", recall)
#     mlflow.log_metric("f1_score", f1_scr)

#     signature = mlflow.models.infer_signature(X_train, best_estimator.predict(X_test))
#     mlflow.sklearn.log_model(best_estimator, "best_model", signature=signature)
#     # save and log file
#     notebook_path = "lr_tfidf_hp.ipynb"
#     os.system(f"jupyter nbconvert --to notebook --execute --inplace {notebook_path}")
#     mlflow.log_artifact(notebook_path)

#     # Print the results for verification
#     print(f"Accuracy: {accuracy}")
#     print(f"Precision: {precision}")
#     print(f"Recall: {recall}")
#     print(f"F1 Score: {f1_scr}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# 🏃 View run 1 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/a99c4e68334f4dc490379a2bb06b9c08
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 2 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/db5400c468a8424aadd4807a072787b9
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 3 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/77616e6d70d1470a98a9c40a50c7060f
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 4 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/40fe12758c9d423295a1a050b3cef7d9
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 5 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/88f18a3c2ec649a48bcb1a7e42dabf26
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 6 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/3e8723cd938b4201be96fbcfa3b75f1d
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 7 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/cfabd9b3cbbf4aa1873e9038378aecaa
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 8 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/a6ef2d71fb824ce98f800c5f5f7182d4
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 9 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/3f67eb3f327e4a3e953071476673d901
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 10 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/08d89fedaee8464c8473c637d03c2d24
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 11 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/feb6ab3dd1594ae0acf8d32c9ee93bf8
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 12 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/f8be64932f4c453883b1bea93256d4ac
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 13 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/1e37a893f370404ea6b636f1572b3e9f
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 14 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/411e031baeb441588c81f27211445dc8
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 15 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/529cab45a94b465a8c9ebd8db9fa8ff4
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 16 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/4bf13a019cfc498088618cc5e123b757
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 17 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/b6d6464da26542d2a25438b64ecccccc
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 18 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/df469a5ad3c54e608e0901ee4760cbfe
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 19 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/19b86ecee182411ca4cd9cd6cc8238c2
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 20 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/ba54f3541e994f5aa9d52b1b7893e359
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 21 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/e1f02f121b7e4b8f96f108b7f7abbb95
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 22 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/ab882d7200184a2ca3130626c4d87274
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 23 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/f8099601fa6a409f80b339e4841ffe6e
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 24 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/5e32ee5835304876aa2a604cedd24cab
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 25 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/319fb47f340d4d568d3950683a4125f0
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 26 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/51e7071e92064cdbaa075e24b041e09c
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 27 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/24bea8a0b86a4892999f589d1502ae69
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 28 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/e235610c6ca34e9ab04bd02a47ccb3b4
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 29 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/5d7f422c741e4fde90771e43c62c6db5
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 30 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/563dbac1c8c743588e4d0e7765ee26f4
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 31 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/9b35394a447d4abdbb038f1910f9cb7e
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 32 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/2906d6e83a92460798bba1b3f391546b
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 33 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/ffa1a7c4c34140f4ba20e26e130a1a3c
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 34 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/f8a480603a5342cda9b55a4c8bdf4d0e
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 35 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/d487e9ef04ab4a8bba5b9dbb5c025102
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# 🏃 View run 36 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/e89e3860437b42769cf3b802bba5d663
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
# Accuracy: 0.8069620253164557
# Precision: 0.6467341306347746
# Recall: 0.8099078341013825
# F1 Score: 0.7191815856777494
# 🏃 View run orderly-lark-906 at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3/runs/a22e6316b0294b8989a045bc0f8a64a8
# 🧪 View experiment at: https://dagshub.com/neerajstd159/mlflow-demo.mlflow/#/experiments/3
